# %%
from langchain_groq import ChatGroq
from ragas.llms import LangchainLLMWrapper
from langchain_ollama import OllamaEmbeddings
import os
from ragas.testset import TestsetGenerator
from langchain_community.document_loaders import DirectoryLoader
from langchain_community.document_loaders import PyPDFLoader  # PDF-specific loader

# %%
os.environ["GROQ_API_KEY"] = "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"

llm = ChatGroq(
    model="llama-3.1-8b-instant",
    temperature=0,
    max_tokens=8000,
    timeout=None,
    max_retries=2,
    
)

# %%
generator_llm = LangchainLLMWrapper(llm)
embeddings = OllamaEmbeddings(model="nomic-embed-text")

# %%
def load_pdfs(pdf_folder_path):
    documents = []
    for file in os.listdir(pdf_folder_path):
        if file.endswith('.pdf'):
            pdf_path = os.path.join(pdf_folder_path, file)
            loader = PyPDFLoader(pdf_path)
            documents.extend(loader.load())

    return documents

# %%
# Path to the directory containing PDFs
path = "data/"

docs = load_pdfs(path)

# %%
llm.invoke("What is the meaning of life?")
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 llm.invoke("What is the meaning of life?")
#
# File c:\Users\Hossa\miniconda3\envs\lang\Lib\site-packages\langchain_core\language_models\chat_models.py:286, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     275 def invoke(
#     276     self,
#     277     input: LanguageModelInput,
#    (...)
#     281     **kwargs: Any,
#     282 ) -> BaseMessage:
#     283     config = ensure_config(config)
#     284     return cast(
#     285         ChatGeneration,
# --> 286         self.generate_prompt(
#     287             [self._convert_input(input)],
#     288             stop=stop,
#     289             callbacks=config.get("callbacks"),
#     290             tags=config.get("tags"),
#     291             metadata=config.get("metadata"),
#     292             run_name=config.get("run_name"),
#     293             run_id=config.pop("run_id", None),
#     294             **kwargs,
#     295         ).generations[0][0],
#     296     ).message
#
# File c:\Users\Hossa\miniconda3\envs\lang\Lib\site-packages\langchain_core\language_models\chat_models.py:786, in generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     777         output.run = [
#     778             RunInfo(run_id=run_manager.run_id) for run_manager in run_managers
#     779         ]
#     780     return output
#     782 def generate_prompt(
#     783     self,
#     784     prompts: list[PromptValue],
#     785     stop: Optional[list[str]] = None,
# --> 786     callbacks: Callbacks = None,
#     787     **kwargs: Any,
#     788 ) -> LLMResult:
#     789     prompt_messages = [p.to_messages() for p in prompts]
#     790     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File c:\Users\Hossa\miniconda3\envs\lang\Lib\site-packages\langchain_core\language_models\chat_models.py:643, in generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     634 for i, m in enumerate(messages):
#     635     try:
#     636         results.append(
#     637             self._generate_with_cache(
#     638                 m,
#     639                 stop=stop,
#     640                 run_manager=run_managers[i] if run_managers else None,
#     641                 **kwargs,
#     642             )
# --> 643         )
#     644     except BaseException as e:
#     645         if run_managers:
#
# File c:\Users\Hossa\miniconda3\envs\lang\Lib\site-packages\langchain_core\language_models\chat_models.py:633, in generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     615 callback_manager = CallbackManager.configure(
#     616     callbacks,
#     617     self.callbacks,
#    (...)
#     622     self.metadata,
#     623 )
#     624 run_managers = callback_manager.on_chat_model_start(
#     625     self._serialized,
#     626     messages,
#    (...)
#     631     batch_size=len(messages),
#     632 )
# --> 633 results = []
#     634 for i, m in enumerate(messages):
#     635     try:
#
# File c:\Users\Hossa\miniconda3\envs\lang\Lib\site-packages\langchain_core\language_models\chat_models.py:851, in _generate_with_cache(self, messages, stop, run_manager, **kwargs)
#     847                 chunk.message.id = f"run-{run_manager.run_id}"
#     848             run_manager.on_llm_new_token(
#     849                 cast(str, chunk.message.content), chunk=chunk
#     850             )
# --> 851         chunks.append(chunk)
#     852     result = generate_from_stream(iter(chunks))
#     853 else:
#
# File c:\Users\Hossa\miniconda3\envs\lang\Lib\site-packages\langchain_groq\chat_models.py:474, in ChatGroq._generate(self, messages, stop, run_manager, **kwargs)
#     469 message_dicts, params = self._create_message_dicts(messages, stop)
#     470 params = {
#     471     **params,
#     472     **kwargs,
#     473 }
# --> 474 response = self.client.create(messages=message_dicts, **params)
#     475 return self._create_chat_result(response)
#
# File c:\Users\Hossa\miniconda3\envs\lang\Lib\site-packages\groq\resources\chat\completions.py:298, in Completions.create(self, messages, model, frequency_penalty, function_call, functions, logit_bias, logprobs, max_tokens, n, parallel_tool_calls, presence_penalty, response_format, seed, stop, stream, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     157 def create(
#     158     self,
#     159     *,
#    (...)
#     186     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     187 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#     188     """
#     189     Creates a model response for the given chat conversation.
#     190
#    (...)
#     296       timeout: Override the client-level default timeout for this request, in seconds
#     297     """
# --> 298     return self._post(
#     299         "/openai/v1/chat/completions",
#     300         body=maybe_transform(
#     301             {
#     302                 "messages": messages,
#     303                 "model": model,
#     304                 "frequency_penalty": frequency_penalty,
#     305                 "function_call": function_call,
#     306                 "functions": functions,
#     307                 "logit_bias": logit_bias,
#     308                 "logprobs": logprobs,
#     309                 "max_tokens": max_tokens,
#     310                 "n": n,
#     311                 "parallel_tool_calls": parallel_tool_calls,
#     312                 "presence_penalty": presence_penalty,
#     313                 "response_format": response_format,
#     314                 "seed": seed,
#     315                 "stop": stop,
#     316                 "stream": stream,
#     317                 "temperature": temperature,
#     318                 "tool_choice": tool_choice,
#     319                 "tools": tools,
#     320                 "top_logprobs": top_logprobs,
#     321                 "top_p": top_p,
#     322                 "user": user,
#     323             },
#     324             completion_create_params.CompletionCreateParams,
#     325         ),
#     326         options=make_request_options(
#     327             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     328         ),
#     329         cast_to=ChatCompletion,
#     330         stream=stream or False,
#     331         stream_cls=Stream[ChatCompletionChunk],
#     332     )
#
# File c:\Users\Hossa\miniconda3\envs\lang\Lib\site-packages\groq\_base_client.py:1263, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1249 def post(
#    1250     self,
#    1251     path: str,
#    (...)
#    1258     stream_cls: type[_StreamT] | None = None,
#    1259 ) -> ResponseT | _StreamT:
#    1260     opts = FinalRequestOptions.construct(
#    1261         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1262     )
# -> 1263     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\Hossa\miniconda3\envs\lang\Lib\site-packages\groq\_base_client.py:955, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     952 else:
#     953     retries_taken = 0
# --> 955 return self._request(
#     956     cast_to=cast_to,
#     957     options=options,
#     958     stream=stream,
#     959     stream_cls=stream_cls,
#     960     retries_taken=retries_taken,
#     961 )
#
# File c:\Users\Hossa\miniconda3\envs\lang\Lib\site-packages\groq\_base_client.py:1058, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1055         err.response.read()
#    1057     log.debug("Re-raising status error")
# -> 1058     raise self._make_status_error_from_response(err.response) from None
#    1060 return self._process_response(
#    1061     cast_to=cast_to,
#    1062     options=options,
#    (...)
#    1066     retries_taken=retries_taken,
#    1067 )
#
# BadRequestError: Error code: 400 - {'error': {'message': 'max_tokens for preview model `llama-3.1-8b-instant` must be less than or equal to 8000', 'type': 'invalid_request_error'}}

# %%
generator = TestsetGenerator(llm=generator_llm, embedding_model=embeddings)
dataset = generator.generate_with_langchain_docs(docs, testset_size=10)
# Out:
# Applying HeadlinesExtractor:   0%|          | 0/114 [00:00<?, ?it/s]
# unable to apply transformation: The LLM generation was not completed. Please increase try increasing the max_tokens and try again.
# unable to apply transformation: The LLM generation was not completed. Please increase try increasing the max_tokens and try again.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[54], line 2
#       1 generator = TestsetGenerator(llm=generator_llm, embedding_model=embeddings)
# ----> 2 dataset = generator.generate_with_langchain_docs(docs, testset_size=10)
#
# File c:\Users\Hossa\miniconda3\envs\lang\Lib\site-packages\ragas\testset\synthesizers\generate.py:185, in TestsetGenerator.generate_with_langchain_docs(self, documents, testset_size, transforms, transforms_llm, transforms_embedding_model, query_distribution, run_config, callbacks, with_debugging_logs, raise_exceptions)
#     182 kg = KnowledgeGraph(nodes=nodes)
#     184 # apply transforms and update the knowledge graph
# --> 185 apply_transforms(kg, transforms)
#     186 self.knowledge_graph = kg
#     188 return self.generate(
#     189     testset_size=testset_size,
#     190     query_distribution=query_distribution,
#    (...)
#     194     raise_exceptions=raise_exceptions,
#     195 )
#
# File c:\Users\Hossa\miniconda3\envs\lang\Lib\site-packages\ragas\testset\transforms\engine.py:106, in apply_transforms(kg, transforms, run_config, callbacks)
#     104 if isinstance(transforms, t.List):
#     105     for transform in transforms:
# --> 106         asyncio.run(
#     107             run_coroutines(
#     108                 transform.generate_execution_plan(kg),
#     109                 get_desc(transform),
#     110                 run_config.max_workers,
#     111             )
#     112         )
#     113 # if Parallel, collect inside it and run it all
#     114 elif isinstance(transforms, Parallel):
#
# File c:\Users\Hossa\miniconda3\envs\lang\Lib\site-packages\nest_asyncio.py:30, in _patch_asyncio.<locals>.run(main, debug)
#      28 task = asyncio.ensure_future(main)
#      29 try:
# ---> 30     return loop.run_until_complete(task)
#      31 finally:
#      32     if not task.done():
#
# File c:\Users\Hossa\miniconda3\envs\lang\Lib\site-packages\nest_asyncio.py:92, in _patch_loop.<locals>.run_until_complete(self, future)
#      90     f._log_destroy_pending = False
#      91 while not f.done():
# ---> 92     self._run_once()
#      93     if self._stopping:
#      94         break
#
# File c:\Users\Hossa\miniconda3\envs\lang\Lib\site-packages\nest_asyncio.py:115, in _patch_loop.<locals>._run_once(self)
#     108     heappop(scheduled)
#     110 timeout = (
#     111     0 if ready or self._stopping
#     112     else min(max(
#     113         scheduled[0]._when - self.time(), 0), 86400) if scheduled
#     114     else None)
# --> 115 event_list = self._selector.select(timeout)
#     116 self._process_events(event_list)
#     118 end_time = self.time() + self._clock_resolution
#
# File c:\Users\Hossa\miniconda3\envs\lang\Lib\selectors.py:314, in SelectSelector.select(self, timeout)
#     312 ready = []
#     313 try:
# --> 314     r, w, _ = self._select(self._readers, self._writers, [], timeout)
#     315 except InterruptedError:
#     316     return ready
#
# File c:\Users\Hossa\miniconda3\envs\lang\Lib\selectors.py:305, in SelectSelector._select(self, r, w, _, timeout)
#     304 def _select(self, r, w, _, timeout=None):
# --> 305     r, w, x = select.select(r, w, w, timeout)
#     306     return r, w + x, []
#
# KeyboardInterrupt:
